# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
# !pip install transformers accelerate bitsandbytes
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 13.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 112.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 83.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 57.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 9.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 63.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig

model_name = "Midu2712/Mistral-7B-Instruct-v0.2-finetuned_Law"

# Quantization settings for 4-bit
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_use_double_quant=True
)

# Load model with 4-bit quantization
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto",
    quantization_config=bnb_config,
    torch_dtype="auto"
)

# Save the quantized model
model.save_pretrained("/content/Mistral-7B-Instruct-v0.2-finetuned_Law_Quantized")
tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.save_pretrained("/content/Mistral-7B-Instruct-v0.2-finetuned_Law_Quantized")
# Out:
# config.json:   0%|          | 0.00/671 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# ...
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.13k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/3.51M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# ('/content/Mistral-7B-Instruct-v0.2-finetuned_Law_Quantized/tokenizer_config.json',
#  '/content/Mistral-7B-Instruct-v0.2-finetuned_Law_Quantized/special_tokens_map.json',
# ...

# %%
from huggingface_hub import create_repo, upload_folder

# Change this to your username on Hugging Face
repo_id ="Midu2712/Mistral-7B-Instruct-v0.2-finetuned_Law-Quantized"

# Upload the quantized model
upload_folder(
    folder_path="/content/Mistral-7B-Instruct-v0.2-finetuned_Law_Quantized",
    repo_id=repo_id,
    commit_message="Add quantized model",
    token="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"
)
# Out:
# Upload 2 LFS files:   0%|          | 0/2 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/4.13G [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/Midu2712/Mistral-7B-Instruct-v0.2-finetuned_Law-Quantized/commit/373008199d2c0be92baa638a9e6b8ed86321d61c', commit_message='Add quantized model', commit_description='', oid='373008199d2c0be92baa638a9e6b8ed86321d61c', pr_url=None, repo_url=RepoUrl('https://huggingface.co/Midu2712/Mistral-7B-Instruct-v0.2-finetuned_Law-Quantized', endpoint='https://huggingface.co', repo_type='model', repo_id='Midu2712/Mistral-7B-Instruct-v0.2-finetuned_Law-Quantized'), pr_revision=None, pr_num=None)

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
import torch

model_name = "Midu2712/Mistral-7B-Instruct-v0.2-finetuned_Law-Quantized"

# Load model and tokenizer
model = AutoModelForCausalLM.from_pretrained(model_name, quantization_config=bnb_config, device_map="auto")
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Function to generate answers
def generate_answer(question):
    input_text = f"### Question:\n{question}\n\n### Answer:\n"
    inputs = tokenizer(input_text, return_tensors="pt").to("cuda")

    with torch.no_grad():
        outputs = model.generate(**inputs, max_new_tokens=150, do_sample=True, temperature=0.7, top_p=0.9)

    answer = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return answer

# Example test
question = "What is the legal treatment of deceptive practices?"
print("Generated Answer:", generate_answer(question))
# Out:
# config.json:   0%|          | 0.00/1.16k [00:00<?, ?B/s]
# Unused kwargs: ['_load_in_4bit', '_load_in_8bit', 'quant_method']. These kwargs are not used in <class 'transformers.utils.quantization_config.BitsAndBytesConfig'>.
# /usr/local/lib/python3.11/dist-packages/transformers/quantizers/auto.py:195: UserWarning: You passed `quantization_config` or equivalent parameters to `from_pretrained` but the model you're loading already has a `quantization_config` attribute. The `quantization_config` from the model will be used.
#   warnings.warn(warning_msg)
# model.safetensors:   0%|          | 0.00/4.13G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.13k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/3.51M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# ...

# %%
# Function to generate answers
def generate_answer(question):
    input_text = f"### Question:\n{question}\n\n### Answer:\n"
    inputs = tokenizer(input_text, return_tensors="pt").to("cuda")

    with torch.no_grad():
        outputs = model.generate(**inputs, max_new_tokens=512, do_sample=True, temperature=0.7, top_p=0.9)

    answer = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return answer

question = "What is the procedure for plea bargaining?"
print("Generated Answer:", generate_answer(question))
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generated Answer: ### Question:
# What is the procedure for plea bargaining?
#
# ### Answer:
#
# Plea bargaining is a negotiation process between the defendant and the prosecutor to reach a resolution of a criminal case without proceeding to trial. The following is a general procedure for plea bargaining:
#
# 1. The defendant is informed of the charges against them and the potential penalties.
# 2. The defendant may consult with an attorney to determine the strengths and weaknesses of their case and to advise them on the potential outcomes of a trial versus a plea bargain.
# 3. The defendant and their attorney may negotiate with the prosecutor to determine if a plea bargain is possible and what the terms of the plea bargain would be.
# 4. If an agreement is reached, the defendant and their attorney will sign a plea agreement document, which outlines the terms of the plea bargain.
# ...

# %%
# Function to generate answers
def generate_answer(question):
    input_text = f"### Question:\n{question}\n\n### Answer:\n"
    inputs = tokenizer(input_text, return_tensors="pt").to("cuda")

    with torch.no_grad():
        outputs = model.generate(**inputs, max_new_tokens=512, do_sample=True, temperature=0.7, top_p=0.9)

    answer = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return answer

question = "Who does the term 'Attorney-General' refer to in this Code in sri lanka?"
print("Generated Answer:", generate_answer(question))
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generated Answer: ### Question:
# Who does the term 'Attorney-General' refer to in this Code in sri lanka?
#
# ### Answer:
# In Sri Lanka, the term 'Attorney-General' refers to the primary legal advisor to the Government and the President of Sri Lanka. The Attorney-General is responsible for providing legal advice to the Government, representing the State in criminal and civil proceedings, and performing various other functions as outlined in the Constitution and the Attorney-General's Act. The Attorney-General is appointed by the President and is a member of the Cabinet of Ministers. In the context of the Sri Lankan Code, the term 'Attorney-General' would refer to the Attorney-General of Sri Lanka.

# %%
question = "What is the procedure for plea bargaining?"
print("Generated Answer:", generate_answer(question))
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generated Answer: ### Question:
# What is the procedure for plea bargaining?
#
# ### Answer:
#
# Plea bargaining is a process in which a defendant agrees to plead guilty or no contest to a crime in exchange for a more lenient sentence or dismissal of other charges. The following is a general outline of the plea bargaining process:
#
# 1. Initial Appearance: The defendant is brought before a judge for the first time, usually in handcuffs and wearing jail clothing. The judge advises the defendant of the charges against them, their constitutional rights, and the possibility of a plea bargain. The defendant may enter a plea of guilty, not guilty, or no contest at this time. If the defendant pleads not guilty, a trial date is set.
# ...
