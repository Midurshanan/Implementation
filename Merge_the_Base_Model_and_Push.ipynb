# %%
# !unzip /content/Mistral-7B-Instruct-v0.1-finetuned_Law.zip -d /content/Mistral-7B-Instruct-v0.1-finetuned_Law
# Out:
# Archive:  /content/Mistral-7B-Instruct-v0.1-finetuned_Law.zip
#   inflating: /content/Mistral-7B-Instruct-v0.1-finetuned_Law/adapter_config.json
#   inflating: /content/Mistral-7B-Instruct-v0.1-finetuned_Law/tokenizer.json
#   inflating: /content/Mistral-7B-Instruct-v0.1-finetuned_Law/tokenizer.model
#   inflating: /content/Mistral-7B-Instruct-v0.1-finetuned_Law/adapter_model.safetensors
#   inflating: /content/Mistral-7B-Instruct-v0.1-finetuned_Law/special_tokens_map.json
#   inflating: /content/Mistral-7B-Instruct-v0.1-finetuned_Law/tokenizer_config.json
#   inflating: /content/Mistral-7B-Instruct-v0.1-finetuned_Law/README.md

# %%
import os #To get ccess to the operating system

# Set the HF_TOKEN environment variable to the provided token
os.environ["HF_TOKEN"] = "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"

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
from peft import PeftModel
import torch

# Load the base model
base_model = "mistralai/Mistral-7B-Instruct-v0.1"
model = AutoModelForCausalLM.from_pretrained(
    base_model,
    low_cpu_mem_usage=True,
    return_dict=True,
    torch_dtype=torch.float16,
    device_map={"": 0}
)

# Load your fine-tuned model's LoRA adapters
model = PeftModel.from_pretrained(model, "/content/Mistral-7B-Instruct-v0.1-finetuned_Law")
model = model.merge_and_unload()  # Merges the LoRA adapters
# Out:
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/25.1k [00:00<?, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.94G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]

# %%
model.save_pretrained("/content/Mistral-7B-Instruct-v0.1-finetuned_Law_Merged")
tokenizer = AutoTokenizer.from_pretrained(base_model)
tokenizer.save_pretrained("/content/Mistral-7B-Instruct-v0.1-finetuned_Law_Merged")
# Out:
# tokenizer_config.json:   0%|          | 0.00/2.10k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# ('/content/Mistral-7B-Instruct-v0.1-finetuned_Law_Merged/tokenizer_config.json',
#  '/content/Mistral-7B-Instruct-v0.1-finetuned_Law_Merged/special_tokens_map.json',
#  '/content/Mistral-7B-Instruct-v0.1-finetuned_Law_Merged/tokenizer.model',
#  '/content/Mistral-7B-Instruct-v0.1-finetuned_Law_Merged/added_tokens.json',
#  '/content/Mistral-7B-Instruct-v0.1-finetuned_Law_Merged/tokenizer.json')

# %%
model.push_to_hub("Midu2712/Mistral-7B-Instruct-v0.1-finetuned_Law", use_auth_token="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")
tokenizer.push_to_hub("Midu2712/Mistral-7B-Instruct-v0.1-finetuned_Law", use_auth_token="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")
# Out:
# model-00003-of-00003.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# Upload 3 LFS files:   0%|          | 0/3 [00:00<?, ?it/s]
# /usr/local/lib/python3.11/dist-packages/transformers/utils/hub.py:894: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# README.md:   0%|          | 0.00/5.17k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# ...
